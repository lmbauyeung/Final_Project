# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
from time import sleep
from random import randint
from datetime import datetime
from pathlib import Path
from imdb import Cinemagoer

# %%
# loading the data from The Numbers
the_numbers_df = pd.read_csv('The_Numbers_data_cleaned.csv')

# %%
the_numbers_df
# Out:
#       index release_date                                        movie  \
# 0         1    4/23/2019                            Avengers: Endgame
# 1         2    5/20/2011  Pirates of the Caribbean: On Stranger Tides
# 2         3    4/22/2015                      Avengers: Age of Ultron
# 3         4   12/16/2015     Star Wars Episode VII: The Force Awakens
# 4         5    4/25/2018                       Avengers: Infinity War
# ...     ...          ...                                          ...
# 6222   6223      Unknown                                       Red 11
# 6223   6224     4/2/1999                                    Following
# 6224   6225    7/13/2005                Return to the Land of Wonders
# 6225   6226    9/29/2015                         A Plague So Pleasant
# 6226   6227     8/5/2005                            My Date With Drew
#
#            budget domestic_gross worldwide_gross
# 0     400,000,000    858,373,000   2,797,800,564
# 1     379,000,000    241,071,802   1,045,713,802
# 2     365,000,000    459,005,868   1,395,316,979
# 3     306,000,000    936,662,225   2,064,615,817
# 4     300,000,000    678,815,482   2,048,359,754
# ...           ...            ...             ...
# 6222        7,000              0               0
# 6223        6,000         48,482         240,495
# 6224        5,000          1,338           1,338
# 6225        1,400              0               0
# 6226        1,100        181,041         181,041
#
# [6227 rows x 6 columns]

# %%
the_numbers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6227 entries, 0 to 6226
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            6227 non-null   int64
#  1   release_date     6227 non-null   object
#  2   movie            6227 non-null   object
#  3   budget           6227 non-null   object
#  4   domestic_gross   6227 non-null   object
#  5   worldwide_gross  6227 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 292.0+ KB

# %%
# changing release_date to datetime
the_numbers_df['release_date'] = pd.to_datetime(the_numbers_df['release_date'], errors ='coerce')

# %%
# converting columns to integer
the_numbers_df['budget'] = the_numbers_df['budget'].str.replace(',','').astype('int64')
the_numbers_df['domestic_gross'] = the_numbers_df['domestic_gross'].str.replace(',','').astype('int64')
the_numbers_df['worldwide_gross'] = the_numbers_df['worldwide_gross'].str.replace(',','').astype('int64')

# %%
the_numbers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6227 entries, 0 to 6226
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            6227 non-null   int64
#  1   release_date     6112 non-null   datetime64[ns]
#  2   movie            6227 non-null   object
#  3   budget           6227 non-null   int64
#  4   domestic_gross   6227 non-null   int64
#  5   worldwide_gross  6227 non-null   int64
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 292.0+ KB

# %%
the_numbers_df.head()
# Out:
#    index release_date                                        movie     budget  \
# 0      1   2019-04-23                            Avengers: Endgame  400000000
# 1      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides  379000000
# 2      3   2015-04-22                      Avengers: Age of Ultron  365000000
# 3      4   2015-12-16     Star Wars Episode VII: The Force Awakens  306000000
# 4      5   2018-04-25                       Avengers: Infinity War  300000000
#
#    domestic_gross  worldwide_gross
# 0       858373000       2797800564
# 1       241071802       1045713802
# 2       459005868       1395316979
# 3       936662225       2064615817
# 4       678815482       2048359754

# %%
# dropping nulls
the_numbers_df.dropna(inplace=True)

# %%
# filtering
# 1. release_date after 1999
# 2. release_date before 2020 (pre-pandemic)
# 3. worldwide_gross >= $500,000
# 4. budget >= $5,000,000 #(the_numbers_df['budget']>=5000000)
budget_df = the_numbers_df[(the_numbers_df['release_date']>='2000-01-01') & (the_numbers_df['release_date']<='2019-12-31') & (the_numbers_df['worldwide_gross']>=500000)]

# %%
budget_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3811 entries, 0 to 6219
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            3811 non-null   int64
#  1   release_date     3811 non-null   datetime64[ns]
#  2   movie            3811 non-null   object
#  3   budget           3811 non-null   int64
#  4   domestic_gross   3811 non-null   int64
#  5   worldwide_gross  3811 non-null   int64
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 208.4+ KB

# %%
# resetting index
budget_df.reset_index(inplace=True)

# %%
# dropping index columns
budget_df.drop(['index', 'level_0'], axis=1, inplace=True)
# Out:
# C:\Users\Bosco\anaconda3\envs\DA_ENV\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
budget_df
# Out:
#      release_date                                        movie     budget  \
# 0      2019-04-23                            Avengers: Endgame  400000000
# 1      2011-05-20  Pirates of the Caribbean: On Stranger Tides  379000000
# 2      2015-04-22                      Avengers: Age of Ultron  365000000
# 3      2015-12-16     Star Wars Episode VII: The Force Awakens  306000000
# 4      2018-04-25                       Avengers: Infinity War  300000000
# ...           ...                                          ...        ...
# 3806   2017-07-07                                A Ghost Story     100000
# 3807   2004-05-07                                Super Size Me      65000
# 3808   2001-03-16                                     Gabriela      50000
# 3809   2001-03-09                                      Dayereh      10000
# 3810   2004-10-08                                       Primer       7000
#
#       domestic_gross  worldwide_gross
# 0          858373000       2797800564
# 1          241071802       1045713802
# 2          459005868       1395316979
# 3          936662225       2064615817
# 4          678815482       2048359754
# ...              ...              ...
# 3806         1594798          2769782
# 3807        11529368         22233808
# 3808         2335352          2335352
# 3809          673780           683509
# 3810          424760           841926
#
# [3811 rows x 5 columns]

# %%
#imdb_rating = []
#main_cast_1 = []
#main_cast_2 = []
#main_cast_3 = []

# %%
# crawling imdb (1st attempt)
print(datetime.now())
for i in range(0,len(budget_df)):
    # searching the movie on imdb
    search_url = 'https://www.imdb.com/search/title/?title=' +str(budget_df['movie'][i])+ '&title_type=feature&release_date=' +str(budget_df['release_date'][i].year)+'-01-01,' +str(budget_df['release_date'][i].year)+ '-12-31'
    response_search = requests.get(search_url)
    soup_search = BeautifulSoup(response_search.content, 'html.parser')
    
    try:
        # obtaining the movie page
        movie_url = 'http://imdb.com'+soup_search.select('h3 a')[0].get('href')
        response = requests.get(movie_url)
        soup = BeautifulSoup(response.content, 'html.parser')

        # adding rating to list
        try:
            rating = soup.select('span.AggregateRatingButton__RatingScore-sc-1ll29m0-1.iTLWoV')[0].get_text()
            imdb_rating.append(rating)
        except:
            imdb_rating.append(np.nan)

        # adding cast 1 to list
        try:
            cast1 = soup.select('div.PrincipalCredits__PrincipalCreditsPanelWideScreen-sc-hdn81t-0.hzbDAm> ul > li:nth-child(3) > div > ul > li:nth-child(1) > a')[0].get_text()
            main_cast_1.append(cast1)
        except:
            main_cast_1.append(np.nan)

        # adding cast 2 to list
        try:
            cast2 = soup.select('div.PrincipalCredits__PrincipalCreditsPanelWideScreen-sc-hdn81t-0.hzbDAm> ul > li:nth-child(3) > div > ul > li:nth-child(2) > a')[0].get_text()
            main_cast_2.append(cast2)
        except:
            main_cast_2.append(np.nan)

        # adding cast 3 to list
        try:
            cast3 = soup.select('div.PrincipalCredits__PrincipalCreditsPanelWideScreen-sc-hdn81t-0.hzbDAm> ul > li:nth-child(3) > div > ul > li:nth-child(3) > a')[0].get_text()
            main_cast_3.append(cast3)
        except:
            main_cast_3.append(np.nan)
            
    except:
        imdb_rating.append(np.nan)
        main_cast_1.append(np.nan)
        main_cast_2.append(np.nan)
        main_cast_3.append(np.nan)
    
    # adding sleep time
    wait_time = 1
    sleep(wait_time)

print(datetime.now())
# Out:
# 2022-03-04 09:00:52.530667
# 2022-03-04 09:32:20.828181

# %%
# creating a dataframe for crawled data
imdb_df = pd.DataFrame(columns=['title','imdb_rating','cast_1','cast_2','cast_3'])

# %%
# filling crawled data into the new dataframe
imdb_df['title'] = budget_df['movie']
imdb_df['imdb_rating'] = imdb_rating
imdb_df['cast_1'] = main_cast_1
imdb_df['cast_2'] = main_cast_2
imdb_df['cast_3'] = main_cast_3

# %%
imdb_df
# Out:
#                                             title imdb_rating  \
# 0                               Avengers: Endgame         8.4
# 1     Pirates of the Caribbean: On Stranger Tides         6.6
# 2                         Avengers: Age of Ultron         7.3
# 3        Star Wars Episode VII: The Force Awakens         7.9
# 4                          Avengers: Infinity War         8.5
# ...                                           ...         ...
# 3806                                A Ghost Story         6.8
# 3807                                Super Size Me         NaN
# 3808                                     Gabriela         4.8
# 3809                                      Dayereh         NaN
# 3810                                       Primer         6.8
#
#                  cast_1           cast_2             cast_3
# 0     Robert Downey Jr.      Chris Evans       Mark Ruffalo
# 1           Johnny Depp    Penélope Cruz        Ian McShane
# 2     Robert Downey Jr.      Chris Evans       Mark Ruffalo
# 3          Daisy Ridley      John Boyega        Oscar Isaac
# 4     Robert Downey Jr.  Chris Hemsworth       Mark Ruffalo
# ...                 ...              ...                ...
# 3806      Casey Affleck      Rooney Mara  McColm Cephas Jr.
# 3807                NaN              NaN                NaN
# 3808        Jaime Gomez      Seidy Lopez      Zach Galligan
# 3809                NaN              NaN                NaN
# 3810      Shane Carruth   David Sullivan       Casey Gooden
#
# [3811 rows x 5 columns]

# %%
# saving the initial imdb_df to a csv 
filepath = Path('imdb_df.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)
imdb_df.to_csv(filepath, index=False)

# %%
# loading the initial imdb_df 
imdb_df = pd.read_csv('imdb_df.csv')

# %%
# creating a dataframe for movies without data (1st attempt)
imdb_missing_df = imdb_df[imdb_df['imdb_rating'].isna()]

# %%
# creating a movie_url column with null values
movie_url = []
for i in range(0,len(imdb_missing_df)):
    movie_url.append(np.nan)
imdb_missing_df['movie_url'] = movie_url
# Out:
# C:\Users\Bosco\AppData\Local\Temp/ipykernel_25920/3302669621.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_missing_df['movie_url'] = movie_url

# %%
# extracting imdb_id for movies
ia = Cinemagoer()
imdb_id = []
for i in range(0, len(imdb_missing_df)):
    try:
        movie = ia.search_movie(imdb_missing_df['title'][i])[0]
        imdb_id.append('tt'+str(ia.get_imdbID(movie)))
    except:
        imdb_id.append(np.nan)

# %%
# updating movie_url based on imdb_id
for i in range(0, len(imdb_missing_df)):
    if type(imdb_missing_df['movie_url'][i]) == float:
        imdb_missing_df['movie_url'][i] = 'https://www.imdb.com/title/'+str(imdb_missing_df['imdb_id'][i])+'/'
    else:
        imdb_missing_df['movie_url'][i] = imdb_missing_df['movie_url'][i]
# Out:
# C:\Users\Bosco\AppData\Local\Temp/ipykernel_6700/2953825205.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_missing_df['movie_url'][i] = imdb_missing_df['movie_url'][i]
# C:\Users\Bosco\AppData\Local\Temp/ipykernel_6700/2953825205.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_missing_df['movie_url'][i] = 'https://www.imdb.com/title/'+str(imdb_missing_df['imdb_id'][i])+'/'

# %%
# updating imdb_id after manually checking and correcting the movie_url
for i in range(0, len(imdb_missing_df)):
    imdb_missing_df['imdb_id'][i] = imdb_missing_df['movie_url'][i].partition('/title/')[-1].partition('/')[0]
# Out:
# C:\Users\Bosco\AppData\Local\Temp/ipykernel_6700/1545459044.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_missing_df['imdb_id'][i] = imdb_missing_df['movie_url'][i].partition('/title/')[-1].partition('/')[0]

# %%
# crawling imdb for missing data (2nd attempt)
print(datetime.now())
for i in range(0, len(imdb_missing_df)):
    response = requests.get(imdb_missing_df['movie_url'][i])
    soup = BeautifulSoup(response.content, 'html.parser')

    # adding rating to list
    try:
        imdb_missing_df['imdb_rating'][i] = soup.select('span.AggregateRatingButton__RatingScore-sc-1ll29m0-1.iTLWoV')[0].get_text()
    except:
        imdb_missing_df['imdb_rating'][i] = np.nan

    # adding cast 1 to list
    try:
        imdb_missing_df['cast_1'][i] = soup.select('div.PrincipalCredits__PrincipalCreditsPanelWideScreen-sc-hdn81t-0.hzbDAm> ul > li:nth-child(3) > div > ul > li:nth-child(1) > a')[0].get_text()
    except:
        imdb_missing_df['cast_1'][i] = np.nan

    # adding cast 2 to list
    try:
        imdb_missing_df['cast_2'][i] = soup.select('div.PrincipalCredits__PrincipalCreditsPanelWideScreen-sc-hdn81t-0.hzbDAm> ul > li:nth-child(3) > div > ul > li:nth-child(2) > a')[0].get_text()
    except:
        imdb_missing_df['cast_2'][i] = np.nan

    # adding cast 3 to list
    try:
        imdb_missing_df['cast_3'][i] = soup.select('div.PrincipalCredits__PrincipalCreditsPanelWideScreen-sc-hdn81t-0.hzbDAm> ul > li:nth-child(3) > div > ul > li:nth-child(3) > a')[0].get_text()
    except:
        imdb_missing_df['cast_3'][i] = np.nan

    # adding sleep time
    wait_time = 1
    sleep(wait_time)

print(datetime.now())
# Out:
# 2022-03-06 15:42:15.498751
# C:\Users\Bosco\AppData\Local\Temp/ipykernel_6700/1083288268.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_missing_df['imdb_rating'][i] = soup.select('span.AggregateRatingButton__RatingScore-sc-1ll29m0-1.iTLWoV')[0].get_text()
# C:\Users\Bosco\AppData\Local\Temp/ipykernel_6700/1083288268.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_missing_df['cast_1'][i] = soup.select('div.PrincipalCredits__PrincipalCreditsPanelWideScreen-sc-hdn81t-0.hzbDAm> ul > li:nth-child(3) > div > ul > li:nth-child(1) > a')[0].get_text()
# C:\Users\Bosco\AppData\Local\Temp/ipykernel_6700/1083288268.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_missing_df['cast_2'][i] = soup.select('div.PrincipalCredits__PrincipalCreditsPanelWideScreen-sc-hdn81t-0.hzbDAm> ul > li:nth-child(3) > div > ul > li:nth-child(2) > a')[0].get_text()
# C:\Users\Bosco\AppData\Local\Temp/ipykernel_6700/1083288268.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_missing_df['cast_3'][i] = soup.select('div.PrincipalCredits__PrincipalCreditsPanelWideScreen-sc-hdn81t-0.hzbDAm> ul > li:nth-child(3) > div > ul > li:nth-child(3) > a')[0].get_text()
# C:\Users\Bosco\AppData\Local\Temp/ipykernel_6700/1083288268.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_missing_df['cast_1'][i] = np.nan
# C:\Users\Bosco\AppData\Local\Temp/ipykernel_6700/1083288268.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_missing_df['cast_2'][i] = np.nan
# C:\Users\Bosco\AppData\Local\Temp/ipykernel_6700/1083288268.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_missing_df['cast_3'][i] = np.nan
# 2022-03-06 16:41:10.595930

# %%
# creating a dataframe for movies without data (2nd attempt)
imdb_missing_df2 = imdb_missing_df[imdb_missing_df['cast_1'].isna()]
imdb_missing_df2
# Out:
#                               title  imdb_rating cast_1 cast_2 cast_3  \
# 35     Michael Jackson's This Is It          7.3    NaN    NaN    NaN
# 137               Shi Yue Wei Cheng          8.4    NaN    NaN    NaN
# 200                           U2 3D          8.4    NaN    NaN    NaN
# 227  Justin Bieber: Never Say Never          1.7    NaN    NaN    NaN
# 240          Katy Perry: Part of Me          5.9    NaN    NaN    NaN
# 282         Hillsong: Let Hope Rise          6.4    NaN    NaN    NaN
# 468                Meet the Mormons          6.8    NaN    NaN    NaN
# 478       In the Shadow of the Moon          8.0    NaN    NaN    NaN
# 504                 The Gatekeepers          7.6    NaN    NaN    NaN
# 528                   Shine a Light          7.1    NaN    NaN    NaN
# 539              The Act of Killing          8.2    NaN    NaN    NaN
# 556                            Rize          7.1    NaN    NaN    NaN
# 569                      Twenty-Two          7.4    NaN    NaN    NaN
# 575              Tupac Resurrection          7.9    NaN    NaN    NaN
#
#                                  movie_url    imdb_id
# 35   https://www.imdb.com/title/tt1477715/  tt1477715
# 137  https://www.imdb.com/title/tt1403130/  tt4559518
# 200  https://www.imdb.com/title/tt0892375/  tt0892375
# 227  https://www.imdb.com/title/tt1702443/  tt1702443
# 240  https://www.imdb.com/title/tt2215719/  tt2215719
# 282  https://www.imdb.com/title/tt3850544/  tt3850544
# 468  https://www.imdb.com/title/tt4003774/  tt4003774
# 478  https://www.imdb.com/title/tt0925248/  tt0925248
# 504  https://www.imdb.com/title/tt2309788/  tt2309788
# 528  https://www.imdb.com/title/tt0893382/  tt0893382
# 539  https://www.imdb.com/title/tt2375605/  tt2375605
# 556  https://www.imdb.com/title/tt0436724/  tt0436724
# 569  https://www.imdb.com/title/tt3843282/  tt3843282
# 575  https://www.imdb.com/title/tt0343121/  tt0343121

# %%
# crawling imdb for missing data (3rd attempt)
print(datetime.now())
for i in range(0, len(imdb_missing_df2)):
    response = requests.get(imdb_missing_df2['movie_url'].iloc[i])
    soup = BeautifulSoup(response.content, 'html.parser')

    # adding cast 1 to list
    try:
        imdb_missing_df2['cast_1'].iloc[i] = soup.select('div.PrincipalCredits__PrincipalCreditsPanelWideScreen-sc-hdn81t-0.hzbDAm > ul > li.ipc-metadata-list__item.ipc-metadata-list-item--link > div > ul > li:nth-child(1) > a')[0].get_text()
    except:
        imdb_missing_df2['cast_1'].iloc[i] = np.nan

    # adding cast 2 to list
    try:
        imdb_missing_df2['cast_2'].iloc[i] = soup.select('div.PrincipalCredits__PrincipalCreditsPanelWideScreen-sc-hdn81t-0.hzbDAm > ul > li.ipc-metadata-list__item.ipc-metadata-list-item--link > div > ul > li:nth-child(2) > a')[0].get_text()
    except:
        imdb_missing_df2['cast_2'].iloc[i] = np.nan

    # adding cast 3 to list
    try:
        imdb_missing_df2['cast_3'].iloc[i] = soup.select('div.PrincipalCredits__PrincipalCreditsPanelWideScreen-sc-hdn81t-0.hzbDAm > ul > li.ipc-metadata-list__item.ipc-metadata-list-item--link > div > ul > li:nth-child(3) > a')[0].get_text()
    except:
        imdb_missing_df2['cast_3'].iloc[i] = np.nan

    # adding sleep time
    wait_time = 1
    sleep(wait_time)

print(datetime.now())
# Out:
# 2022-03-06 18:09:25.094437
# 2022-03-06 18:10:38.709188

# %%
# substituting missing values in imdb_missing_df from imdb_missing_df2
index = imdb_missing_df[imdb_missing_df['cast_1'].isna()].index
for i in range(0, len(imdb_missing_df2)):    
    imdb_missing_df[index[i]:index[i]+1]['imdb_rating'] = imdb_missing_df2['imdb_rating'].iloc[i]
    imdb_missing_df[index[i]:index[i]+1]['cast_1'] = imdb_missing_df2['cast_1'].iloc[i]
    imdb_missing_df[index[i]:index[i]+1]['cast_2'] = imdb_missing_df2['cast_2'].iloc[i]
    imdb_missing_df[index[i]:index[i]+1]['cast_3'] = imdb_missing_df2['cast_3'].iloc[i]
# Out:
# C:\Users\Bosco\AppData\Local\Temp/ipykernel_6700/2299578141.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_missing_df[index[i]:index[i]+1]['imdb_rating'] = imdb_missing_df2['imdb_rating'].iloc[i]
# C:\Users\Bosco\AppData\Local\Temp/ipykernel_6700/2299578141.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_missing_df[index[i]:index[i]+1]['cast_1'] = imdb_missing_df2['cast_1'].iloc[i]
# C:\Users\Bosco\AppData\Local\Temp/ipykernel_6700/2299578141.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_missing_df[index[i]:index[i]+1]['cast_2'] = imdb_missing_df2['cast_2'].iloc[i]
# C:\Users\Bosco\AppData\Local\Temp/ipykernel_6700/2299578141.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_missing_df[index[i]:index[i]+1]['cast_3'] = imdb_missing_df2['cast_3'].iloc[i]

# %%
# saving the imdb_missing_df
filepath = Path('imdb_missing_df.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)
imdb_missing_df.to_csv(filepath, index=False)

# %%
# substituting missing values in imdb_df from imdb_missing_df
index = imdb_df[imdb_df['imdb_rating'].isna()].index
for i in range(0, len(imdb_missing_df)):    
    imdb_df[index[i]:index[i]+1]['imdb_rating'] = imdb_missing_df['imdb_rating'].iloc[i]
    imdb_df[index[i]:index[i]+1]['cast_1'] = imdb_missing_df['cast_1'].iloc[i]
    imdb_df[index[i]:index[i]+1]['cast_2'] = imdb_missing_df['cast_2'].iloc[i]
    imdb_df[index[i]:index[i]+1]['cast_3'] = imdb_missing_df['cast_3'].iloc[i]
# Out:
# C:\Users\Bosco\AppData\Local\Temp/ipykernel_6700/2661722492.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_df[index[i]:index[i]+1]['imdb_rating'] = imdb_missing_df['imdb_rating'].iloc[i]
# C:\Users\Bosco\AppData\Local\Temp/ipykernel_6700/2661722492.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_df[index[i]:index[i]+1]['cast_1'] = imdb_missing_df['cast_1'].iloc[i]
# C:\Users\Bosco\AppData\Local\Temp/ipykernel_6700/2661722492.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_df[index[i]:index[i]+1]['cast_2'] = imdb_missing_df['cast_2'].iloc[i]
# C:\Users\Bosco\AppData\Local\Temp/ipykernel_6700/2661722492.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_df[index[i]:index[i]+1]['cast_3'] = imdb_missing_df['cast_3'].iloc[i]

# %%
# adding the movie_url and imdb_id to the imdb_df and saving it to a new dataframe
imdb_full_df = imdb_df.merge(imdb_missing_df, how='left', on=['title', 'imdb_rating', 'cast_1', 'cast_2', 'cast_3'])

# %%
# checking null values for imdb_full_df
imdb_full_df.isna().sum()
# Out:
# title             0
# imdb_rating       0
# cast_1            0
# cast_2            0
# cast_3            5
# movie_url      3220
# imdb_id        3220
# dtype: int64

# %%
# fetching all imdb_id
for i in range(0, len(imdb_full_df)):
    if type(imdb_full_df['imdb_id'][i]) == float:
        try:
            movie = ia.search_movie(imdb_full_df['title'][i])[0]
            imdb_full_df['imdb_id'][i] = 'tt'+str(ia.get_imdbID(movie))
        except:
            imdb_full_df['imdb_id'][i] = np.nan
# Out:
# C:\Users\Bosco\AppData\Local\Temp/ipykernel_6700/2938924743.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_full_df['imdb_id'][i] = 'tt'+str(ia.get_imdbID(movie))
# 2022-03-06 19:21:18,854 CRITICAL [imdbpy] C:\Users\Bosco\anaconda3\envs\DA_ENV\lib\site-packages\imdb\_exceptions.py:32: IMDbParserError exception raised; args: ('invalid title: """"',); kwds: {}
# NoneType: None
# C:\Users\Bosco\AppData\Local\Temp/ipykernel_6700/2938924743.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_full_df['imdb_id'][i] = np.nan
# 2022-03-06 19:35:08,352 CRITICAL [imdbpy] C:\Users\Bosco\anaconda3\envs\DA_ENV\lib\site-packages\imdb\_exceptions.py:32: IMDbParserError exception raised; args: ('invalid title: """"',); kwds: {}
# NoneType: None
# 2022-03-06 19:38:55,688 CRITICAL [imdbpy] C:\Users\Bosco\anaconda3\envs\DA_ENV\lib\site-packages\imdb\_exceptions.py:32: IMDbParserError exception raised; args: ('invalid title: """"',); kwds: {}
# NoneType: None
# 2022-03-06 19:42:30,901 CRITICAL [imdbpy] C:\Users\Bosco\anaconda3\envs\DA_ENV\lib\site-packages\imdb\_exceptions.py:32: IMDbParserError exception raised; args: ('invalid title: """"',); kwds: {}
# NoneType: None
# 2022-03-06 19:50:50,286 CRITICAL [imdbpy] C:\Users\Bosco\anaconda3\envs\DA_ENV\lib\site-packages\imdb\_exceptions.py:32: IMDbParserError exception raised; args: ('invalid title: """"',); kwds: {}
# NoneType: None

# %%
# filling movie_url from imdb_db
for i in range(0, len(imdb_full_df)):
    if type(imdb_full_df['movie_url'][i]) == float:
        imdb_full_df['movie_url'][i] = 'https://www.imdb.com/title/'+imdb_full_df['imdb_id'][i]+'/'
    else:
        imdb_full_df['movie_url'][i] = imdb_full_df['movie_url'][i]
# Out:
# C:\Users\Bosco\AppData\Local\Temp/ipykernel_6700/388353747.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_full_df['movie_url'][i] = 'https://www.imdb.com/title/'+imdb_full_df['imdb_id'][i]+'/'
# C:\Users\Bosco\AppData\Local\Temp/ipykernel_6700/388353747.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_full_df['movie_url'][i] = imdb_full_df['movie_url'][i]

# %%
# saving the imdb_full_df
filepath = Path('imdb_full_df.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)
imdb_full_df.to_csv(filepath, index=False)

# %%
# loading the imdb_full_df
imdb_full_df = pd.read_csv('imdb_full_df.csv')

# %%
# creating lists for extra movie info
imdb_rating_check = []
runtime = []
director = []
genre = []

# %%
# fetching extra movie info
print(datetime.now())
for i in range(0, len(imdb_raw_df)):
    try:
        movie = ia.get_movie(imdb_raw_df['imdb_id'][i].partition('tt')[-1])
        imdb_rating_check.append(movie.get('rating'))
        runtime.append(movie.get('runtimes'))
        genre.append(movie.get('genres'))
        director.append(str(movie.get('director')[0]))
    except:
        imdb_rating_check.append(np.nan)
        runtime.append(np.nan)
        genre.append(np.nan)
        director.append(np.nan)
print(datetime.now())
# Out:
# 2022-03-07 21:23:42.392624
# 2022-03-07 22:17:20.403529

# %%
# creating a dataframe for extra data
imdb_extra_df = pd.DataFrame(columns=['rating_check', 'runtime', 'genre'])
imdb_extra_df['rating_check'] = imdb_rating_check
imdb_extra_df['runtime'] = runtime
imdb_extra_df['genre'] = genre
imdb_extra_df['director'] = director

# %%
imdb_extra_df
# Out:
#       rating_check  runtime                                       genre  \
# 0              8.4  ['181']  ['Action', 'Adventure', 'Drama', 'Sci-Fi']
# 1              6.6  ['137']          ['Action', 'Adventure', 'Fantasy']
# 2              7.3  ['141']           ['Action', 'Adventure', 'Sci-Fi']
# 3              7.9  ['138']           ['Action', 'Adventure', 'Sci-Fi']
# 4              8.5  ['149']           ['Action', 'Adventure', 'Sci-Fi']
# ...            ...      ...                                         ...
# 3309           7.5   ['89']                        ['Comedy', 'Horror']
# 3310           6.1   ['90']                ['Crime', 'Thriller', 'War']
# 3311           7.4  ['105']                ['Comedy', 'Drama', 'Music']
# 3312           7.2  ['102']              ['Crime', 'Drama', 'Thriller']
# 3313           4.3   ['90']                ['Drama', 'Family', 'Music']
#
#              director
# 0       Anthony Russo
# 1        Rob Marshall
# 2         Joss Whedon
# 3         J.J. Abrams
# 4       Anthony Russo
# ...               ...
# 3309        Eli Craig
# 3310   Brian De Palma
# 3311  William H. Macy
# 3312  Jaume Balagueró
# 3313     Jim Amatulli
#
# [3314 rows x 4 columns]

# %%
# saving the imdb_extra_df
filepath = Path('imdb_extra_df.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)
imdb_extra_df.to_csv(filepath, index=False)

# %%
# loading the imdb_extra_df 
imdb_extra_df = pd.read_csv('imdb_extra_df.csv')

# %%
# merging the budget_df and imdb_full_df
imdb_raw_df = pd.concat([budget_df, imdb_full_df], axis=1)
imdb_raw_df
# Out:
#      release_date                                        movie     budget  \
# 0      2019-04-23                            Avengers: Endgame  400000000
# 1      2011-05-20  Pirates of the Caribbean: On Stranger Tides  379000000
# 2      2015-04-22                      Avengers: Age of Ultron  365000000
# 3      2015-12-16     Star Wars Episode VII: The Force Awakens  306000000
# 4      2018-04-25                       Avengers: Infinity War  300000000
# ...           ...                                          ...        ...
# 3806   2017-07-07                                A Ghost Story     100000
# 3807   2004-05-07                                Super Size Me      65000
# 3808   2001-03-16                                     Gabriela      50000
# 3809   2001-03-09                                      Dayereh      10000
# 3810   2004-10-08                                       Primer       7000
#
#       domestic_gross  worldwide_gross  \
# 0          858373000       2797800564
# 1          241071802       1045713802
# 2          459005868       1395316979
# 3          936662225       2064615817
# 4          678815482       2048359754
# ...              ...              ...
# 3806         1594798          2769782
# 3807        11529368         22233808
# 3808         2335352          2335352
# 3809          673780           683509
# 3810          424760           841926
#
#                                             title  imdb_rating  \
# 0                               Avengers: Endgame          8.4
# 1     Pirates of the Caribbean: On Stranger Tides          6.6
# 2                         Avengers: Age of Ultron          7.3
# 3        Star Wars Episode VII: The Force Awakens          7.9
# 4                          Avengers: Infinity War          8.5
# ...                                           ...          ...
# 3806                                A Ghost Story          6.8
# 3807                                Super Size Me          7.2
# 3808                                     Gabriela          4.8
# 3809                                      Dayereh          7.4
# 3810                                       Primer          6.8
#
#                      cast_1             cast_2             cast_3  \
# 0         Robert Downey Jr.        Chris Evans       Mark Ruffalo
# 1               Johnny Depp      Penélope Cruz        Ian McShane
# 2         Robert Downey Jr.        Chris Evans       Mark Ruffalo
# 3              Daisy Ridley        John Boyega        Oscar Isaac
# 4         Robert Downey Jr.    Chris Hemsworth       Mark Ruffalo
# ...                     ...                ...                ...
# 3806          Casey Affleck        Rooney Mara  McColm Cephas Jr.
# 3807        Morgan Spurlock       Daryl Isaacs    Chemeeka Walker
# 3808            Jaime Gomez        Seidy Lopez      Zach Galligan
# 3809  Maryiam Palvin Almani  Nargess Mamizadeh   Mojgan Faramarzi
# 3810          Shane Carruth     David Sullivan       Casey Gooden
#
#                                   movie_url    imdb_id         director
# 0     https://www.imdb.com/title/tt4154796/  tt4154796    Anthony Russo
# 1     https://www.imdb.com/title/tt1298650/  tt1298650     Rob Marshall
# 2     https://www.imdb.com/title/tt2395427/  tt2395427      Joss Whedon
# 3     https://www.imdb.com/title/tt2488496/  tt2488496      J.J. Abrams
# 4     https://www.imdb.com/title/tt4154756/  tt4154756    Anthony Russo
# ...                                     ...        ...              ...
# 3806  https://www.imdb.com/title/tt6265828/  tt6265828     David Lowery
# 3807  https://www.imdb.com/title/tt0390521/  tt0390521  Morgan Spurlock
# 3808  https://www.imdb.com/title/tt0085575/  tt0085575    Bruno Barreto
# 3809  https://www.imdb.com/title/tt0255094/  tt0255094     Jafar Panahi
# 3810  https://www.imdb.com/title/tt0390384/  tt0390384    Shane Carruth
#
# [3811 rows x 13 columns]

# %%
# dropping movies with duplicate title
imdb_raw_df.drop_duplicates(subset=['movie'],inplace=True)
imdb_raw_df
# Out:
#      release_date                                        movie     budget  \
# 0      2019-04-23                            Avengers: Endgame  400000000
# 1      2011-05-20  Pirates of the Caribbean: On Stranger Tides  379000000
# 2      2015-04-22                      Avengers: Age of Ultron  365000000
# 3      2015-12-16     Star Wars Episode VII: The Force Awakens  306000000
# 4      2018-04-25                       Avengers: Infinity War  300000000
# ...           ...                                          ...        ...
# 3806   2017-07-07                                A Ghost Story     100000
# 3807   2004-05-07                                Super Size Me      65000
# 3808   2001-03-16                                     Gabriela      50000
# 3809   2001-03-09                                      Dayereh      10000
# 3810   2004-10-08                                       Primer       7000
#
#       domestic_gross  worldwide_gross  \
# 0          858373000       2797800564
# 1          241071802       1045713802
# 2          459005868       1395316979
# 3          936662225       2064615817
# 4          678815482       2048359754
# ...              ...              ...
# 3806         1594798          2769782
# 3807        11529368         22233808
# 3808         2335352          2335352
# 3809          673780           683509
# 3810          424760           841926
#
#                                             title  imdb_rating  \
# 0                               Avengers: Endgame          8.4
# 1     Pirates of the Caribbean: On Stranger Tides          6.6
# 2                         Avengers: Age of Ultron          7.3
# 3        Star Wars Episode VII: The Force Awakens          7.9
# 4                          Avengers: Infinity War          8.5
# ...                                           ...          ...
# 3806                                A Ghost Story          6.8
# 3807                                Super Size Me          7.2
# 3808                                     Gabriela          4.8
# 3809                                      Dayereh          7.4
# 3810                                       Primer          6.8
#
#                      cast_1             cast_2             cast_3  \
# 0         Robert Downey Jr.        Chris Evans       Mark Ruffalo
# 1               Johnny Depp      Penélope Cruz        Ian McShane
# 2         Robert Downey Jr.        Chris Evans       Mark Ruffalo
# 3              Daisy Ridley        John Boyega        Oscar Isaac
# 4         Robert Downey Jr.    Chris Hemsworth       Mark Ruffalo
# ...                     ...                ...                ...
# 3806          Casey Affleck        Rooney Mara  McColm Cephas Jr.
# 3807        Morgan Spurlock       Daryl Isaacs    Chemeeka Walker
# 3808            Jaime Gomez        Seidy Lopez      Zach Galligan
# 3809  Maryiam Palvin Almani  Nargess Mamizadeh   Mojgan Faramarzi
# 3810          Shane Carruth     David Sullivan       Casey Gooden
#
#                                   movie_url    imdb_id         director
# 0     https://www.imdb.com/title/tt4154796/  tt4154796    Anthony Russo
# 1     https://www.imdb.com/title/tt1298650/  tt1298650     Rob Marshall
# 2     https://www.imdb.com/title/tt2395427/  tt2395427      Joss Whedon
# 3     https://www.imdb.com/title/tt2488496/  tt2488496      J.J. Abrams
# 4     https://www.imdb.com/title/tt4154756/  tt4154756    Anthony Russo
# ...                                     ...        ...              ...
# 3806  https://www.imdb.com/title/tt6265828/  tt6265828     David Lowery
# 3807  https://www.imdb.com/title/tt0390521/  tt0390521  Morgan Spurlock
# 3808  https://www.imdb.com/title/tt0085575/  tt0085575    Bruno Barreto
# 3809  https://www.imdb.com/title/tt0255094/  tt0255094     Jafar Panahi
# 3810  https://www.imdb.com/title/tt0390384/  tt0390384    Shane Carruth
#
# [3793 rows x 13 columns]

# %%
# filtering movies with budget >= $5,000,000
imdb_raw_df = imdb_raw_df[imdb_raw_df['budget']>=5000000]

# %%
# resetting index
imdb_raw_df.reset_index(inplace=True)

# %%
# dropping duplicate column
imdb_raw_df.drop(columns=['movie'], inplace=True)
imdb_raw_df
# Out:
# C:\Users\Bosco\anaconda3\envs\DA_ENV\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#      release_date     budget  domestic_gross  worldwide_gross  \
# 0      2019-04-23  400000000       858373000       2797800564
# 1      2011-05-20  379000000       241071802       1045713802
# 2      2015-04-22  365000000       459005868       1395316979
# 3      2015-12-16  306000000       936662225       2064615817
# 4      2018-04-25  300000000       678815482       2048359754
# ...           ...        ...             ...              ...
# 3309   2011-09-30    5000000          223838          5476793
# 3310   2007-11-16    5000000           65388           861325
# 3311   2014-10-17    5000000           56001           584499
# 3312   2012-05-17    5000000               0          9109597
# 3313   2009-07-07    5000000               0          4568257
#
#                                             title  imdb_rating  \
# 0                               Avengers: Endgame          8.4
# 1     Pirates of the Caribbean: On Stranger Tides          6.6
# 2                         Avengers: Age of Ultron          7.3
# 3        Star Wars Episode VII: The Force Awakens          7.9
# 4                          Avengers: Infinity War          8.5
# ...                                           ...          ...
# 3309                       Tucker & Dale vs. Evil          7.5
# 3310                                     Redacted          6.1
# 3311                                   Rudderless          7.4
# 3312                             Mientras duermes          7.2
# 3313                                    Flying By          4.3
#
#                  cast_1            cast_2            cast_3  \
# 0     Robert Downey Jr.       Chris Evans      Mark Ruffalo
# 1           Johnny Depp     Penélope Cruz       Ian McShane
# 2     Robert Downey Jr.       Chris Evans      Mark Ruffalo
# 3          Daisy Ridley       John Boyega       Oscar Isaac
# 4     Robert Downey Jr.   Chris Hemsworth      Mark Ruffalo
# ...                 ...               ...               ...
# 3309       Tyler Labine        Alan Tudyk    Katrina Bowden
# 3310    Patrick Carroll       Rob Devaney         Izzy Diaz
# 3311       Billy Crudup     Anton Yelchin  Felicity Huffman
# 3312         Luis Tosar       Marta Etura  Alberto San Juan
# 3313    Billy Ray Cyrus  Heather Locklear     Patricia Neal
#
#                                   movie_url    imdb_id         director
# 0     https://www.imdb.com/title/tt4154796/  tt4154796    Anthony Russo
# 1     https://www.imdb.com/title/tt1298650/  tt1298650     Rob Marshall
# 2     https://www.imdb.com/title/tt2395427/  tt2395427      Joss Whedon
# 3     https://www.imdb.com/title/tt2488496/  tt2488496      J.J. Abrams
# 4     https://www.imdb.com/title/tt4154756/  tt4154756    Anthony Russo
# ...                                     ...        ...              ...
# 3309  https://www.imdb.com/title/tt1465522/  tt1465522        Eli Craig
# 3310  https://www.imdb.com/title/tt0937237/  tt0937237   Brian De Palma
# 3311  https://www.imdb.com/title/tt1798243/  tt1798243  William H. Macy
# 3312  https://www.imdb.com/title/tt1437358/  tt1437358  Jaume Balagueró
# 3313  https://www.imdb.com/title/tt1131732/  tt1131732     Jim Amatulli
#
# [3314 rows x 12 columns]

# %%
# saving the imdb_raw_df
filepath = Path('imdb_raw_df.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)
imdb_raw_df.to_csv(filepath, index=False)

# %%
# loading the imdb_raw_df 
imdb_raw_df = pd.read_csv('imdb_raw_df.csv')

# %%
# merging the imdb_raw_df and imdb_extra_df
imdb_full_info_df = pd.concat([imdb_raw_df, imdb_extra_df], axis=1)
imdb_full_info_df
# Out:
#      release_date     budget  domestic_gross  worldwide_gross  \
# 0      2019-04-23  400000000       858373000       2797800564
# 1      2011-05-20  379000000       241071802       1045713802
# 2      2015-04-22  365000000       459005868       1395316979
# 3      2015-12-16  306000000       936662225       2064615817
# 4      2018-04-25  300000000       678815482       2048359754
# ...           ...        ...             ...              ...
# 3309   2011-09-30    5000000          223838          5476793
# 3310   2007-11-16    5000000           65388           861325
# 3311   2014-10-17    5000000           56001           584499
# 3312   2012-05-17    5000000               0          9109597
# 3313   2009-07-07    5000000               0          4568257
#
#                                             title  imdb_rating  \
# 0                               Avengers: Endgame          8.4
# 1     Pirates of the Caribbean: On Stranger Tides          6.6
# 2                         Avengers: Age of Ultron          7.3
# 3        Star Wars Episode VII: The Force Awakens          7.9
# 4                          Avengers: Infinity War          8.5
# ...                                           ...          ...
# 3309                       Tucker & Dale vs. Evil          7.5
# 3310                                     Redacted          6.1
# 3311                                   Rudderless          7.4
# 3312                             Mientras duermes          7.2
# 3313                                    Flying By          4.3
#
#                  cast_1            cast_2            cast_3  \
# 0     Robert Downey Jr.       Chris Evans      Mark Ruffalo
# 1           Johnny Depp     Penélope Cruz       Ian McShane
# 2     Robert Downey Jr.       Chris Evans      Mark Ruffalo
# 3          Daisy Ridley       John Boyega       Oscar Isaac
# 4     Robert Downey Jr.   Chris Hemsworth      Mark Ruffalo
# ...                 ...               ...               ...
# 3309       Tyler Labine        Alan Tudyk    Katrina Bowden
# 3310    Patrick Carroll       Rob Devaney         Izzy Diaz
# 3311       Billy Crudup     Anton Yelchin  Felicity Huffman
# 3312         Luis Tosar       Marta Etura  Alberto San Juan
# 3313    Billy Ray Cyrus  Heather Locklear     Patricia Neal
#
#                                   movie_url    imdb_id         director  \
# 0     https://www.imdb.com/title/tt4154796/  tt4154796    Anthony Russo
# 1     https://www.imdb.com/title/tt1298650/  tt1298650     Rob Marshall
# 2     https://www.imdb.com/title/tt2395427/  tt2395427      Joss Whedon
# 3     https://www.imdb.com/title/tt2488496/  tt2488496      J.J. Abrams
# 4     https://www.imdb.com/title/tt4154756/  tt4154756    Anthony Russo
# ...                                     ...        ...              ...
# 3309  https://www.imdb.com/title/tt1465522/  tt1465522        Eli Craig
# 3310  https://www.imdb.com/title/tt0937237/  tt0937237   Brian De Palma
# 3311  https://www.imdb.com/title/tt1798243/  tt1798243  William H. Macy
# 3312  https://www.imdb.com/title/tt1437358/  tt1437358  Jaume Balagueró
# 3313  https://www.imdb.com/title/tt1131732/  tt1131732     Jim Amatulli
#
#       rating_check  runtime                                       genre  \
# 0              8.4  ['181']  ['Action', 'Adventure', 'Drama', 'Sci-Fi']
# 1              6.6  ['137']          ['Action', 'Adventure', 'Fantasy']
# 2              7.3  ['141']           ['Action', 'Adventure', 'Sci-Fi']
# 3              7.9  ['138']           ['Action', 'Adventure', 'Sci-Fi']
# 4              8.5  ['149']           ['Action', 'Adventure', 'Sci-Fi']
# ...            ...      ...                                         ...
# 3309           7.5   ['89']                        ['Comedy', 'Horror']
# 3310           6.1   ['90']                ['Crime', 'Thriller', 'War']
# 3311           7.4  ['105']                ['Comedy', 'Drama', 'Music']
# 3312           7.2  ['102']              ['Crime', 'Drama', 'Thriller']
# 3313           4.3   ['90']                ['Drama', 'Family', 'Music']
#
#              director
# 0       Anthony Russo
# 1        Rob Marshall
# 2         Joss Whedon
# 3         J.J. Abrams
# 4       Anthony Russo
# ...               ...
# 3309        Eli Craig
# 3310   Brian De Palma
# 3311  William H. Macy
# 3312  Jaume Balagueró
# 3313     Jim Amatulli
#
# [3314 rows x 16 columns]

# %%
imdb_full_info_df.isna().sum()
# Out:
# release_date        0
# budget              0
# domestic_gross      0
# worldwide_gross     0
# title               0
# imdb_rating         0
# cast_1              0
# cast_2              0
# cast_3              4
# movie_url           0
# imdb_id             0
# director           92
# rating_check        0
# runtime             0
# genre               0
# director            0
# dtype: int64

# %%
# saving the imdb_full_info_df
filepath = Path('imdb_full_info_df.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)
imdb_full_info_df.to_csv(filepath, index=False)

# %%
# loading the Merged_df_corrected_scores_and_language
merged_df = pd.read_csv('Merged_df_corrected_scores_and_language.csv', sep=';')

# %%
merged_df.drop(columns=['title_x', 'producer','director_x', 'genre', 'release_date_x', 'budget_x', 'domestic_gross_x', 'worldwide_gross_x',
       'imdb_rating', 'cast_1', 'cast_2', 'cast_3', 'movie_url', 'imdb_id','director_y'], inplace=True)

# %%
# merging the 2 dataframes
final_v0_df = pd.concat([imdb_full_info_df, merged_df], axis=1)

# %%
final_v0_df.drop(columns=['movie_url', 'imdb_id', 'rating_check'], axis=1, inplace=True)

# %%
final_v0_df.isna().sum()
# Out:
# release_date           0
# budget                 0
# domestic_gross         0
# worldwide_gross        0
# title                  0
# imdb_rating            0
# cast_1                 0
# cast_2                 0
# cast_3                 4
# director              92
# runtime                0
# genre                  0
# director               0
# tomatometer_score     37
# audience_score_rt     10
# original_language     21
# MPA_Ratings          120
# dtype: int64

# %%
# Out:
# 17

# %%
combined_df.drop(columns=['title_x', 'release_date_x', 'budget_x', 'domestic_gross_x', 'worldwide_gross_x', 'director'], inplace=True)

# %%
combined_df
# Out:
#       tomatometer_score  audience_score_rt original_language MPA_Ratings  \
# 0                  94.0               90.0           English       PG-13
# 1                  33.0               54.0           English       PG-13
# 2                  76.0               83.0           English       PG-13
# 3                  93.0               85.0           English       PG-13
# 4                  85.0               91.0           English       PG-13
# ...                 ...                ...               ...         ...
# 3309               85.0               85.0           English           R
# 3310               45.0               45.0           English           R
# 3311               64.0               83.0           English           R
# 3312               91.0               78.0   Jaume Balagueró         NaN
# 3313                NaN               18.0      Jim Amatulli         NaN
#
#      release_date     budget  domestic_gross  worldwide_gross  \
# 0      2019-04-23  400000000       858373000       2797800564
# 1      2011-05-20  379000000       241071802       1045713802
# 2      2015-04-22  365000000       459005868       1395316979
# 3      2015-12-16  306000000       936662225       2064615817
# 4      2018-04-25  300000000       678815482       2048359754
# ...           ...        ...             ...              ...
# 3309   2011-09-30    5000000          223838          5476793
# 3310   2007-11-16    5000000           65388           861325
# 3311   2014-10-17    5000000           56001           584499
# 3312   2012-05-17    5000000               0          9109597
# 3313   2009-07-07    5000000               0          4568257
#
#                                             title  imdb_rating  \
# 0                               Avengers: Endgame          8.4
# 1     Pirates of the Caribbean: On Stranger Tides          6.6
# 2                         Avengers: Age of Ultron          7.3
# 3        Star Wars Episode VII: The Force Awakens          7.9
# 4                          Avengers: Infinity War          8.5
# ...                                           ...          ...
# 3309                       Tucker & Dale vs. Evil          7.5
# 3310                                     Redacted          6.1
# 3311                                   Rudderless          7.4
# 3312                             Mientras duermes          7.2
# 3313                                    Flying By          4.3
#
#                  cast_1            cast_2            cast_3  \
# 0     Robert Downey Jr.       Chris Evans      Mark Ruffalo
# 1           Johnny Depp     Penélope Cruz       Ian McShane
# 2     Robert Downey Jr.       Chris Evans      Mark Ruffalo
# 3          Daisy Ridley       John Boyega       Oscar Isaac
# 4     Robert Downey Jr.   Chris Hemsworth      Mark Ruffalo
# ...                 ...               ...               ...
# 3309       Tyler Labine        Alan Tudyk    Katrina Bowden
# 3310    Patrick Carroll       Rob Devaney         Izzy Diaz
# 3311       Billy Crudup     Anton Yelchin  Felicity Huffman
# 3312         Luis Tosar       Marta Etura  Alberto San Juan
# 3313    Billy Ray Cyrus  Heather Locklear     Patricia Neal
#
#                                   movie_url    imdb_id
# 0     https://www.imdb.com/title/tt4154796/  tt4154796
# 1     https://www.imdb.com/title/tt1298650/  tt1298650
# 2     https://www.imdb.com/title/tt2395427/  tt2395427
# 3     https://www.imdb.com/title/tt2488496/  tt2488496
# 4     https://www.imdb.com/title/tt4154756/  tt4154756
# ...                                     ...        ...
# 3309  https://www.imdb.com/title/tt1465522/  tt1465522
# 3310  https://www.imdb.com/title/tt0937237/  tt0937237
# 3311  https://www.imdb.com/title/tt1798243/  tt1798243
# 3312  https://www.imdb.com/title/tt1437358/  tt1437358
# 3313  https://www.imdb.com/title/tt1131732/  tt1131732
#
# [3314 rows x 15 columns]

# %%
# merging the combined_df and imdb_extra_df
full_info_df = pd.concat([combined_df, imdb_extra_df], axis=1)
full_info_df
# Out:
#       tomatometer_score  audience_score_rt original_language MPA_Ratings  \
# 0                  94.0               90.0           English       PG-13
# 1                  33.0               54.0           English       PG-13
# 2                  76.0               83.0           English       PG-13
# 3                  93.0               85.0           English       PG-13
# 4                  85.0               91.0           English       PG-13
# ...                 ...                ...               ...         ...
# 3309               85.0               85.0           English           R
# 3310               45.0               45.0           English           R
# 3311               64.0               83.0           English           R
# 3312               91.0               78.0   Jaume Balagueró         NaN
# 3313                NaN               18.0      Jim Amatulli         NaN
#
#      release_date     budget  domestic_gross  worldwide_gross  \
# 0      2019-04-23  400000000       858373000       2797800564
# 1      2011-05-20  379000000       241071802       1045713802
# 2      2015-04-22  365000000       459005868       1395316979
# 3      2015-12-16  306000000       936662225       2064615817
# 4      2018-04-25  300000000       678815482       2048359754
# ...           ...        ...             ...              ...
# 3309   2011-09-30    5000000          223838          5476793
# 3310   2007-11-16    5000000           65388           861325
# 3311   2014-10-17    5000000           56001           584499
# 3312   2012-05-17    5000000               0          9109597
# 3313   2009-07-07    5000000               0          4568257
#
#                                             title  imdb_rating  \
# 0                               Avengers: Endgame          8.4
# 1     Pirates of the Caribbean: On Stranger Tides          6.6
# 2                         Avengers: Age of Ultron          7.3
# 3        Star Wars Episode VII: The Force Awakens          7.9
# 4                          Avengers: Infinity War          8.5
# ...                                           ...          ...
# 3309                       Tucker & Dale vs. Evil          7.5
# 3310                                     Redacted          6.1
# 3311                                   Rudderless          7.4
# 3312                             Mientras duermes          7.2
# 3313                                    Flying By          4.3
#
#                  cast_1            cast_2            cast_3  \
# 0     Robert Downey Jr.       Chris Evans      Mark Ruffalo
# 1           Johnny Depp     Penélope Cruz       Ian McShane
# 2     Robert Downey Jr.       Chris Evans      Mark Ruffalo
# 3          Daisy Ridley       John Boyega       Oscar Isaac
# 4     Robert Downey Jr.   Chris Hemsworth      Mark Ruffalo
# ...                 ...               ...               ...
# 3309       Tyler Labine        Alan Tudyk    Katrina Bowden
# 3310    Patrick Carroll       Rob Devaney         Izzy Diaz
# 3311       Billy Crudup     Anton Yelchin  Felicity Huffman
# 3312         Luis Tosar       Marta Etura  Alberto San Juan
# 3313    Billy Ray Cyrus  Heather Locklear     Patricia Neal
#
#                                   movie_url    imdb_id  rating_check runtime  \
# 0     https://www.imdb.com/title/tt4154796/  tt4154796           8.4   [181]
# 1     https://www.imdb.com/title/tt1298650/  tt1298650           6.6   [137]
# 2     https://www.imdb.com/title/tt2395427/  tt2395427           7.3   [141]
# 3     https://www.imdb.com/title/tt2488496/  tt2488496           7.9   [138]
# 4     https://www.imdb.com/title/tt4154756/  tt4154756           8.5   [149]
# ...                                     ...        ...           ...     ...
# 3309  https://www.imdb.com/title/tt1465522/  tt1465522           7.5    [89]
# 3310  https://www.imdb.com/title/tt0937237/  tt0937237           6.1    [90]
# 3311  https://www.imdb.com/title/tt1798243/  tt1798243           7.4   [105]
# 3312  https://www.imdb.com/title/tt1437358/  tt1437358           7.2   [102]
# 3313  https://www.imdb.com/title/tt1131732/  tt1131732           4.3    [90]
#
#                                    genre         director
# 0     [Action, Adventure, Drama, Sci-Fi]    Anthony Russo
# 1           [Action, Adventure, Fantasy]     Rob Marshall
# 2            [Action, Adventure, Sci-Fi]      Joss Whedon
# 3            [Action, Adventure, Sci-Fi]      J.J. Abrams
# 4            [Action, Adventure, Sci-Fi]    Anthony Russo
# ...                                  ...              ...
# 3309                    [Comedy, Horror]        Eli Craig
# 3310              [Crime, Thriller, War]   Brian De Palma
# 3311              [Comedy, Drama, Music]  William H. Macy
# 3312            [Crime, Drama, Thriller]  Jaume Balagueró
# 3313              [Drama, Family, Music]     Jim Amatulli
#
# [3314 rows x 19 columns]

# %%
# saving the full_info_df
filepath = Path('full_info_df.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)
full_info_df.to_csv(filepath, index=False)

# %%
# saving the final_v0_df
filepath = Path('final_v0_df.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)
final_v0_df.to_csv(filepath, index=False)

# %%
movie.infoset2keys
# Out:
# {'main': ['localized title',
#   'cast',
#   'genres',
#   'runtimes',
#   'countries',
#   'country codes',
#   'language codes',
#   'color info',
#   'aspect ratio',
#   'sound mix',
#   'box office',
#   'certificates',
#   'original air date',
#   'rating',
#   'votes',
#   'cover url',
#   'imdbID',
#   'plot outline',
#   'languages',
#   'title',
#   'year',
#   'kind',
#   'original title',
#   'director',
#   'writer',
#   'producer',
#   'composer',
#   'cinematographer',
#   'editor',
#   'editorial department',
#   'casting director',
#   'production design',
#   'art direction',
#   'set decoration',
#   'costume designer',
#   'make up',
#   'production manager',
#   'assistant director',
#   'art department',
#   'sound crew',
#   'special effects',
#   'visual effects',
#   'stunt performer',
#   'camera and electrical department',
#   'animation department',
#   'casting department',
#   'costume department',
#   'location management',
#   'music department',
#   'script department',
#   'transportation department',
#   'miscellaneous crew',
#   'thanks',
#   'akas',
#   'top 250 rank',
#   'production companies',
#   'distributors',
#   'special effects companies',
#   'other companies'],
#  'plot': ['plot', 'synopsis']}

# %%
merged_df = pd.read_csv('Merged_df.csv')

# %%
Merged_df_corrected_scores = pd.read_csv('Merged_df_corrected_scores.csv', sep=';')

# %%
merged_df['tomatometer_score'] = Merged_df_corrected_scores['tomatometer_score']
merged_df['audience_score_rt'] = Merged_df_corrected_scores['audience_score_rt']
merged_df['MPA_Ratings'] = Merged_df_corrected_scores['MPA_Ratings']

# %%
merged_df.drop(columns=['producer', 'director_x', 'genre', 'movie', 'imdb_rating', 'cast_1', 'cast_2', 'cast_3', 'movie_url', 'imdb_id', 'director_y'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6700/1150866249.py in <module>
# ----> 1 merged_df.drop(columns=['producer', 'director_x', 'genre', 'movie', 'imdb_rating', 'cast_1', 'cast_2', 'cast_3', 'movie_url', 'imdb_id', 'director_y'], inplace=True)
#
# ~\anaconda3\envs\DA_ENV\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\DA_ENV\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\envs\DA_ENV\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\anaconda3\envs\DA_ENV\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\anaconda3\envs\DA_ENV\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['producer' 'director_x' 'genre' 'movie' 'imdb_rating' 'cast_1' 'cast_2'\n 'cast_3' 'movie_url' 'imdb_id' 'director_y'] not found in axis"

# %%
combined_df = pd.concat([merged_df, imdb_raw_df], axis=1)
combined_df
# Out:
#                                           title_x  tomatometer_score  \
# 0                               Avengers: Endgame               94.0
# 1     Pirates of the Caribbean: On Stranger Tides               33.0
# 2                         Avengers: Age of Ultron               76.0
# 3        Star Wars Episode VII: The Force Awakens               93.0
# 4                          Avengers: Infinity War               85.0
# ...                                           ...                ...
# 3309                       Tucker & Dale vs. Evil               85.0
# 3310                                     Redacted               45.0
# 3311                                   Rudderless               64.0
# 3312                             Mientras duermes               91.0
# 3313                                    Flying By                NaN
#
#       audience_score_rt original_language MPA_Ratings release_date_x  \
# 0                  90.0           English       PG-13     2019-04-23
# 1                  54.0           English       PG-13     2011-05-20
# 2                  83.0           English       PG-13     2015-04-22
# 3                  85.0           English       PG-13     2015-12-16
# 4                  91.0           English       PG-13     2018-04-25
# ...                 ...               ...         ...            ...
# 3309               85.0           English           R     2011-09-30
# 3310               45.0           English           R     2007-11-16
# 3311               83.0           English           R     2014-10-17
# 3312               78.0   Jaume Balagueró         NaN     2012-05-17
# 3313               18.0      Jim Amatulli         NaN     2009-07-07
#
#        budget_x  domestic_gross_x  worldwide_gross_x release_date  ...  \
# 0     400000000         858373000         2797800564   2019-04-23  ...
# 1     379000000         241071802         1045713802   2011-05-20  ...
# 2     365000000         459005868         1395316979   2015-04-22  ...
# 3     306000000         936662225         2064615817   2015-12-16  ...
# 4     300000000         678815482         2048359754   2018-04-25  ...
# ...         ...               ...                ...          ...  ...
# 3309    5000000            223838            5476793   2011-09-30  ...
# 3310    5000000             65388             861325   2007-11-16  ...
# 3311    5000000             56001             584499   2014-10-17  ...
# 3312    5000000                 0            9109597   2012-05-17  ...
# 3313    5000000                 0            4568257   2009-07-07  ...
#
#       domestic_gross  worldwide_gross  \
# 0          858373000       2797800564
# 1          241071802       1045713802
# 2          459005868       1395316979
# 3          936662225       2064615817
# 4          678815482       2048359754
# ...              ...              ...
# 3309          223838          5476793
# 3310           65388           861325
# 3311           56001           584499
# 3312               0          9109597
# 3313               0          4568257
#
#                                             title imdb_rating  \
# 0                               Avengers: Endgame         8.4
# 1     Pirates of the Caribbean: On Stranger Tides         6.6
# 2                         Avengers: Age of Ultron         7.3
# 3        Star Wars Episode VII: The Force Awakens         7.9
# 4                          Avengers: Infinity War         8.5
# ...                                           ...         ...
# 3309                       Tucker & Dale vs. Evil         7.5
# 3310                                     Redacted         6.1
# 3311                                   Rudderless         7.4
# 3312                             Mientras duermes         7.2
# 3313                                    Flying By         4.3
#
#                  cast_1            cast_2            cast_3  \
# 0     Robert Downey Jr.       Chris Evans      Mark Ruffalo
# 1           Johnny Depp     Penélope Cruz       Ian McShane
# 2     Robert Downey Jr.       Chris Evans      Mark Ruffalo
# 3          Daisy Ridley       John Boyega       Oscar Isaac
# 4     Robert Downey Jr.   Chris Hemsworth      Mark Ruffalo
# ...                 ...               ...               ...
# 3309       Tyler Labine        Alan Tudyk    Katrina Bowden
# 3310    Patrick Carroll       Rob Devaney         Izzy Diaz
# 3311       Billy Crudup     Anton Yelchin  Felicity Huffman
# 3312         Luis Tosar       Marta Etura  Alberto San Juan
# 3313    Billy Ray Cyrus  Heather Locklear     Patricia Neal
#
#                                   movie_url    imdb_id         director
# 0     https://www.imdb.com/title/tt4154796/  tt4154796    Anthony Russo
# 1     https://www.imdb.com/title/tt1298650/  tt1298650     Rob Marshall
# 2     https://www.imdb.com/title/tt2395427/  tt2395427      Joss Whedon
# 3     https://www.imdb.com/title/tt2488496/  tt2488496      J.J. Abrams
# 4     https://www.imdb.com/title/tt4154756/  tt4154756    Anthony Russo
# ...                                     ...        ...              ...
# 3309  https://www.imdb.com/title/tt1465522/  tt1465522        Eli Craig
# 3310  https://www.imdb.com/title/tt0937237/  tt0937237   Brian De Palma
# 3311  https://www.imdb.com/title/tt1798243/  tt1798243  William H. Macy
# 3312  https://www.imdb.com/title/tt1437358/  tt1437358  Jaume Balagueró
# 3313  https://www.imdb.com/title/tt1131732/  tt1131732     Jim Amatulli
#
# [3314 rows x 21 columns]

# %%
# saving the combined_df
filepath = Path('combined_df.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)
combined_df.to_csv(filepath, index=False)

# %%
combined_df.isna().sum()
# Out:
# title_x                0
# tomatometer_score     32
# audience_score_rt     15
# original_language     26
# MPA_Ratings          155
# release_date_x         0
# budget_x               0
# domestic_gross_x       0
# worldwide_gross_x      0
# release_date           0
# budget                 0
# domestic_gross         0
# worldwide_gross        0
# title                  0
# imdb_rating            0
# cast_1                 0
# cast_2                 0
# cast_3                 4
# movie_url              0
# imdb_id                0
# director              92
# dtype: int64
